# %%
d1={
    'Mechanical': [
        "Hardness", "Ductility", "Yield Strength", "Wear Resistance", "Microhardness",
        "Toughness", "Fracture Toughness", "Elongation", "Tensile Strength", "Creep",
        "Elastic Modulus", "Yield Stress", "Wear resistance", "Ultimate Tensile Strength",
        "Compressive Strength", "Young's Modulus", "Brittleness", "Fracture Strain",
        "Fracture Strength", "Vickers microhardness", "Nanohardness", "Plastic Strain",
        "Creep Resistance", "Wear Rate", "Friction Coefficient", "Shear Modulus",
        "Micro-hardness", "Compressive Yield Strength", "Dislocation Density",
        "Fatigue", "Compressive Yield Stress", "Creep Rate", "Elastic Constants",
        "Strain", "Bulk Modulus", "Fatigue Resistance", "High Temperature Strength",
        "Poisson's Ratio", "Young's modulus", "Uniform Elongation", "Shear Strength",
        "Wear", "Ultimate Strength", "Flexural Strength", "Abrasion Resistance",
        "Stiffness", "Yield stress", "Bulk modulus", "Elastic Moduli",
        "Coefficient of Friction", "Wear rate", "Mechanical Strength",
        "Maximum Stress", "Flow Stress", "Fracture toughness", "Elastic modulus"
    ],
    
    'Thermal': [
        "Thermal Conductivity", "Curie Temperature", "Seebeck Coefficient",
        "Heat Capacity", "Thermal conductivity", "Thermal Diffusivity",
        "Melting Point", "Thermal Expansion Coefficient", "Characteristic Temperatures"
    ],
    
    'Electrical': [
        "Electrical Conductivity", "Resistivity", "Conductivity",
        "Electrical Resistivity", "Superconductivity"
    ],
    
    'Magnetic': [
        "Magnetization", "Magnetic Entropy Change", "Coercivity", "Magnetocaloric",
        "Saturation Magnetization", "Magnetocaloric Effect", "Curie temperature"
    ],
    
    'Chemical': [
        "Catalytic Activity", "Electronegativity", "Overpotential",
        "Mixing Entropy", "Pitting Potential", "Electrocatalytic Activity",
        "Catalytic Performance", "Mixing Enthalpy"
    ],
    
    'Structural': [
        "GFA", "Stacking Fault Energy", "SFE", "Crystal Structure"
    ],
    
    'Surface': [
        "ECSA", "Permeability", "Friction"
    ],
    
    'Other Properties': [
        "Entropy", "Entropy Change", "Refrigerant Capacity",
        "Refrigeration Capacity", "Elasticity", "Enthalpy", "Activation Energy",
        "Valence Electron Concentration"
    ],
    
    'Unknown': []
}

d2={
    'Mechanical': [
        "Nano-hardness", "Room Temperature Strength", "Young s Modulus", "Residual Stress",
        "Hardening Rate", "Compressive Plasticity", "Specific Strength", "High Strength",
        "Compressive Strength", "Compressive Strain", "Fracture", "Fracture Elongation",
        "Tensile Elongation", "Work Hardening Rate", "Total Elongation", "UTS",
        "Tensile Strength", "Compression Strength", "Fatigue Strength", "Impact Toughness",
        "Bending Strength", "Elastic Constants", "Fatigue Resistance", "Fracture Strength",
        "CRSS"
    ],
    
    'Thermal': [
        "Thermal Expansion", "Relative Cooling Power", "Ductile Brittle Transition Temperature",
        "Specific Heat", "Adiabatic Temperature Change", "Specific Heat Capacity",
        "Lattice Thermal Conductivity", "Coefficient of Thermal Expansion", "Thermal Diffusivity",
        "Melting Temperature", "Crystallization Temperature", "Heat Capacity",
        "Thermal Hysteresis"
    ],
    
    'Electrical': [
        "Power Factor", "Electrical Resistivity", "Electrical Conductivity",
        "Carrier Concentration", "Carrier Mobility", "Seebeck Coefficient", "Current Density",
        "Figure of Merit"
    ],
    
    'Magnetic': [
        "Hysteresis", "Magnetic Entropy", "Magnetic Entropy Change", "Saturation Magnetization",
        "Magnetoresistance", "Magnetic Moment", "Magnetic Susceptibility"
    ],
    
    'Chemical': [
        "Catalytic Activity", "Oxidation Behavior", "Oxidation Resistance", "Passivation",
        "Pitting Corrosion Resistance", "Electronegativity Difference", "Mixing Entropy",
        "ORR Activity"
    ],
    
    'Structural': [
        "Lattice Parameter", "Twinning", "Phase Composition", "Crystallinity",
        "Crystallite Size", "Lattice Constant", "Phases", "Critical Diameter",
        "Lattice Strain", "Lattice Parameters"
    ],
    
    'Surface': [
        "Surface Roughness", "Surface Area", "Adhesion Strength", "Pitting Resistance"
    ],
    
    'Other Properties': [
        "Relative Density", "Sound Velocity", "Capacity", "Mass Activity",
        "Transition Temperature", "Activation Volume", "High-Temperature Strength",
        "Coarsening Resistance", "Valence Electron Concentration", "Poisson's Ratio",
        "Weldability"
    ],
    
    'Unknown': [
        "Discharge Capacity", "Radiation Resistance", "Diffusion"
    ]
}

d3={
    'Mechanical': [
        "Damping Capacity", "Plastic Strain", "Strain Hardening Rate", "Fracture Strain",
        "Vickers Micro-Hardness", "Poisson s Ratio", "Friction Coefficient",
        "Tensile Yield Stress", "Strain to Failure", "Compressive Stress",
        "Fatigue Life", "Specific Yield Strength", "Total Strain", "Wear Rates",
        "Tensile Ductility", "Bonding Strength", "Work-Hardening Rate",
        "Friction Resistance", "Friction Stress", "Bending Ductility",
        "Nano Hardness", "Indentation Modulus", "Creep Strength",
        "Critical Resolved Shear Stress", "Shear Strain", "Ultimate Tensile Strength",
        "Stress", "Compressive Ductility"
    ],
    
    'Thermal': [
        "Glass Transition Temperature", "Debye Temperature", "Specific Heat",
        "Specific Heat Capacity", "Thermal Resistance", "Refrigerant Capacity",
        "Coefficient of Thermal Expansion", "Liquidus Temperature"
    ],
    
    'Electrical': [
        "zT", "Capacitance", "Permittivity", "Charge Transfer Impedance", "Band Gap"
    ],
    
    'Magnetic': [
        "Magnetism", "Coercive Force", "Magnetocaloric Properties", "Magnetocaloric Properties",
        "Magnetic Hysteresis", "Magnetic Moments", "Saturated Magnetization", "Hc"
    ],
    
    'Chemical': [
        "Mixing Enthalpy", "OER Activity", "Corrosion Potential", "Tafel Slope",
        "HER Activity", "Corrosion Current Density", "MOR Activity",
        "Exchange Current Density"
    ],
    
    'Structural': [
        "Crystal Structure", "Glass Forming Ability", "Lattice Constant",
        "Lattice Parameters", "Lattice Constants", "Lattice Friction Stress",
        "Glass-Forming Ability", "Ligament Size"
    ],
    
    'Surface': [
        "SA", "Adhesion", "Particle Size", "Roughness", "Coefficient of Friction",
        "Surface Energy"
    ],
    
    'Other Properties': [
        "Swelling", "Configurational Entropy", "Irradiation Hardness",
        "Radiation Tolerance", "Cohesive Energy", "Vibrational Entropy",
        "Energy Density", "TOF", "Tg", "Irradiation Tolerance",
        "Hydrogen Absorption Kinetics"
    ],
    
    'Unknown': [
        "Hydrogen Storage Capacity", "Hydrogen Capacity", "Diffusivity",
        "Composition", "Chemical Composition", "Erosion Resistance",
        "Radiation Tolerance"
    ]
}

d4={
    'Mechanical': [
        "Ultimate Compressive Strength", "Wear Rates", "Spall Strength", "Residual Stresses",
        "Strain Hardening Coefficient", "Fracture Resistance", "Creep Exponent", 
        "Resistance to Irradiation Hardening", "Crack Resistance", "Compressive Yield Strength",
        "Elastic Elongation", "Nano-Hardness", "Vickers Microhardness",
        "Nanoindentation Hardness", "Strain Hardening Exponent",
        "Cyclic Fatigue Resistance", "Cavitation Erosion Resistance",
        "Strain Rate", "Compressive Fracture Strength", "YS"
    ],
    
    'Thermal': [
        "Melting Point", "Heat Resistance", "Thermal Expansion Coefficients",
        "Transformation Temperatures", "Volumetric Thermal Expansion",
        "Cooling Power", "Thermal Expansion Coefficient",
        "Grüneisen Coefficient", "Working Temperature Range"
    ],
    
    'Electrical': [
        "Carrier Concentration", "Hall Coefficient", "DOS Effective Mass",
        "Breakdown Potential", "Work Function"
    ],
    
    'Magnetic': [
        "Magnetostriction", "Susceptibility", "Remanence",
        "Static Magnetism", "Magnetic Softness", "Ferromagnetism",
        "Saturated Magnetization", "Magnetisation", "Magnetic Entropy Changes"
    ],
    
    'Chemical': [
        "Oxidation Rate", "Corrosion Rate", "Dehydrogenation Enthalpy",
        "CO Poisoning Tolerance", "Poisoning Resistance",
        "Corrosion Current Density", "Hmix"
    ],
    
    'Structural': [
        "Phase Composition", "Lattice Parameter", "Phase Structures",
        "Martensitic Transformation Temperature", "Phase Structure",
        "Crystal Structures", "Unit Cell Volume", "Interstitial Content",
        "Phase"
    ],
    
    'Surface': [
        "Surface Roughness", "Indentation Hardness", "Reflection Loss",
        "Pore Size", "Wear Volume"
    ],
    
    'Other Properties': [
        "Electrocatalytic Activities", "OER", "Turnover Frequency",
        "Irradiation Hardening Resistance", "Adiabatic Bulk Modulus",
        "Glass-Forming Ability", "Reversible Capacity",
        "Specific Capacity", "Electrochemically Active Surface Area"
    ],
    
    'Unknown': [
        "Wetting", "Adiabatic Bulk Modulus", "Tm", "Ms",
        "VEC", "Tl", "Tx", "S", "Volume Fraction", "Atomic Size Difference"
    ]
}

d5={
    'Mechanical': [
        "Shear Stress", "Yielding Strength", "Specific Compressive Strength", 
        "Ultimate Shear Strength", "Micro Hardness", "Tensile Strain", "High Temperature Strength", 
        "Elongation to Fracture", "Hot Hardness", "Compressive Strain", "Shear Deformation", 
        "Compression Yield Strength", "Fracture Energy", "Compression Strength", 
        "Work-Hardening Rate", "Twinning Stress", "Ultimate Strength", "Modulus of Elasticity", 
        "Strain-Hardening Rate", "Transverse Rupture Strength", "Compression Ratio", 
        "Compressive Plastic Strain", "Wear-Resistance", "Adhesive Strength", "Volume Change", 
        "Wear Volume", "Yield Strengths", "Plastic Deformation Resistance", 
        "Abrasive Wear Resistance", "Cutting Force", "Work-Hardening Capacity", "Strain Rate"
    ],
    
    'Thermal': [
        "Isothermal Entropy Change", "Phase Transition Temperature", "Solidus Temperature", 
        "Refrigeration Capacity", "Softening Coefficient", "Temperature Stability"
    ],
    
    'Electrical': [
        "Dielectric Constant", "Ionic Conductivity", "Electrical Resistance", 
        "Critical Current Density", "Discharge Potential", "Thermoelectric Performance"
    ],
    
    'Magnetic': [
        "Eddy Current Loss", "Magnetic Transition Temperature", "Isothermal Magnetic Entropy Change", 
        "Coercive Field", "Coercive Force", "Hysteresis Losses", "Magnetocaloric Response"
    ],
    
    'Chemical': [
        "Corrosion Rate", "Resistance to CO Poisoning", "Pitting Potential", 
        "Electrocatalytic Activity", "Hydrogen Embrittlement Resistance", 
        "Hydrogen Absorption Capacity", "Pitting Corrosion", "Corrosion Parameters", 
        "Oxidation Kinetics", "Charge Transfer Resistance", "Reaction Kinetics", "Overpotentials"
    ],
    
    'Structural': [
        "Lattice Distortion", "Vacancy Formation Energy", "Grain Boundary Energy", 
        "Phase Constituents", "Structural Transformation", "Lattice Strain", 
        "Unit Cell Volume", "Point Defects", "Lamellar Widths"
    ],
    
    'Surface': [
        "Reflectivity", "Hydrophilicity", "Specific Surface Area"
    ],
    
    'Other Properties': [
        "Glass-Forming Ability", "Capacity Retention Rate", "ECSA Loss", "Compressibility", 
        "Gibbs Free Energy", "Elemental Distribution", "Cell Volume", "Uniformity", 
        "Heterogeneity", "Castability", "Damping", "Aging Resistance", 
        "Weight Loss Rate", "Cost"
    ],
    
    'Unknown': [
        "UE", "MA Loss"
    ]
}

d6={
    'Mechanical': [
        "Fracture energy", "Tensile Uniform Elongation", "Intrinsic Hardness", "Macrohardness", 
        "Rupture Strain", "True Stress", "Micro-Hardness", "Rockwell Hardness", "Work Hardening Capacity", 
        "Yield Strain", "Fatigue Limit", "Compressive Fracture Strain", "Flexural Strength", 
        "Brittleness Index", "Recoverable Strain", "Malleability", "Elongation Rate"
    ],

    'Thermal': [
        "Service Temperature", "CTE", "Heat Resistance", "TEC", "Curie Temperatures", 
        "Temperature Resistance", "Temperature Range", "Working Temperature Window", 
        "Cutting Temperature", "Pasty Range"
    ],

    'Electrical': [
        "Hall Carrier Concentration", "Electronic Conductivity", "Electronic Thermal Conductivity", 
        "Hall Coefficient", "Figure-of-Merit", "Charge Transfer", "Carrier Mobility", "Hall Mobility", 
        "Thermoelectric Figure of Merit", "Attenuation Constant"
    ],

    'Magnetic': [
        "Magnetic Moment", "Magnetic Transition Temperature", "Upper Critical Fields", "Core Loss", 
        "Hysteresis Loss", "Exchange Bias Field", "Effective Permeability", "EM Absorption Performance"
    ],

    'Chemical': [
        "CO Stripping Peak", "Activation Energy", "Passive Current Density", "Redox Peak Potentials", 
        "Local Corrosion Resistance", "Hydrogen Solubility", "Methanol Adsorption Energy", 
        "Enthalpy of Hydride Formation", "Free Energy", "Enthalpy of Mixing", "Dehydrogenation Entropy", 
        "Tribocorrosion Resistance"
    ],

    'Structural': [
        "Atomic Radius", "Elemental Composition", "Elastic Constant", "True Strain", 
        "Threshold Displacement Energy", "Formation Energy", "Vacancy Formation Energy", 
        "Cohesive Energies", "Elastic Moduli", "Sound Velocities", "Pugh Ratio", "Interfacial Energy", 
        "Crack-Growth Rates"
    ],

    'Surface': [
        "Surface Area", "Surface Energies", "Surface Fracture Energy", "Contact Angle"
    ],

    'Other Properties': [
        "Cycling Durability", "Total Loss", "Mass Activity", "Plateau Pressure", "Optical Band Gap", 
        "Absorption Bandwidth", "Wear Mass Loss", "Specific Wear Rate", "Peak Area", 
        "Equilibrium Pressure", "Volumetric Expansion", "Coarsening Rate", "Glass Transition", 
        "Reversible Hydrogen Storage Capacity", "Transition Temperatures"
    ],

    'Unknown': [
        "Figure-of-Merit", "Effective Mass" 
    ]
}

d7= {
    "Mechanical": [
        "Bulk Moduli", "Energy Absorption Capacity", "Cauchy pressure", "Percent elongation",
        "Internal Friction", "Hall-Petch Coefficient", "Ultimate Tensile Elongation", "Ultimate Strain",
        "Internal Strain", "Young modulus", "Indentation Moduli", "Failure Strain", "Steady-State Flow",
        "Coefficient of Plasticity", "Ideal Shear Strength", "Shear stress", "Compression performance",
        "Impact Resistance", "Elastic Strain Energy", "Deformation Resistance", "True stress",
        "Elastic Strain Limit", "Cohesive Strength", "Micro Vickers hardness", "Tensile Stress",
        "Compressive Ultimate Strength", "Plastic Strain to Failure", "Mechanical Hardness",
        "Threshold Stress Intensity Factor", "Ductile fracture", "Pugh s ratio", "Compression Strain",
        "Strain-hardening Rate", "Tensile ductility"
    ],
    "Thermal": [
        "Thermal expansion", "Gr neisen Coefficient", "Thermal Diffusion Coefficient",
        "Debye temperature", "Thermal emittance", "Thermal Softening Resistance",
        "High Temperature Softening Resistance", "Solidus temperature", "Cooling Rate",
        "Linear Thermal Expansivity", "Phase Transformation Entropy", "Thermopower",
        "Onset temperature", "Melting temperature", "High Thermal Conductivity", "Thermal diffusion coefficient"
    ],
    "Electrical": [
        "Hole Concentration", "Hall Carrier Mobility", "Band gap", "Dielectric Loss",
        "Hall mobility", "Electron Mean Free Path", "Complex Permittivity",
        "Electronic thermal conductivity", "Seebeck Coefficients",
        "Temperature coefficient of resistivity", "Critical current density",
        "Electrical resistance", "Cell Voltage"
    ],
    "Magnetic": [
        "Curie Point", "Magnetic entropy changes", "Saturation Magnetic Flux Density",
        "Magnetocrystalline anisotropy", "Magnetic Moments", "Magnetostriction coefficient",
        "Magnetic-field-induced Strain", "AC coercivity", "Saturation magnetisation",
        "Magnetostrain", "Magnetic Saturation", "Coercive field", "Hysteresis losses"
    ],
    "Chemical": [
        "Electrochemical Durability", "Hydrogen absorption capacity", "MOR Onset Potential",
        "Oxygen adsorption energy", "Smix", "Hydrogen evolution kinetics", "EOR",
        "Bond Strength", "Formation Enthalpy", "Hydrogen permeability",
        "Hydrogen Adsorption Impedance", "Metal-H Bond Strength", "H Pick-up",
        "Formation energy", "Dissociation Pressure", "Cytotoxicity"
    ],
    "Structural": [
        "Crystallization Kinetics", "Relative density", "Grain Structure", "Mass Density",
        "Volume fraction", "Polycrystalline elastic modulus", "Room temperature crystal structure",
        "Wall Thickness", "Volume Fractions", "Twin Fault Probability", "Elemental distribution",
        "Phase Compositions", "Average Grain Size", "Grain Growth Kinetics", "Short-range Order"
    ],
    "Surface": [
        "Surface Hardness", "Pitting corrosion potential", "Reflectance", "Effective Surface Area",
        "Median Pore Size", "Indentation Fracture Toughness", "Apparent Density",
        "Size Distribution", "Average Particle Size", "Volume Expansion Coefficient",
        "Solar Absorptance", "Solar absorptance"
    ],
    "Other Properties": [
        "Specific Peak Current Density", "Energy Release Efficiency", "Entropy Changes",
        "Diffusion Rate", "Diffusion Resistance", "Stacking-Fault Energy", "Configurational entropy",
        "Mass Loss", "Output Power Density", "Performance-Cost Ratio", "Rate Capability",
        "Coulombic Efficiency", "Cycling Longevity", "ORR Catalytic Activity",
        "Storage Capacity", "Conversion Efficiency", "Specific capacitance",
        "Faradaic Efficiency"
    ],
    "Unknown": [
        "Zener Ratio", "Dislocation-core Diffusion", "Indentation-energy factor",
        "Dislocation width", "Resistance to Shear Localization", "Effective Refrigerant Capacities",
        "Gibbs free energy", "TL", "Coefficient of Performance", "Helmholtz Free Energy",
        "Twin Strength", "Spallation Resistance", "Volume Wear Rate", "CMAS Resistance",
        "Mass transfer rate", "Bio-corrosion Resistance", "H Species Adsorption",
        "Sommerfeld Coefficient", "Volume change", "Radiation Damage", "Radiation damage"
    ]
}

d8={
    "Mechanical": [
        "Ultimate tensile stress", "Dynamic Compressive Strength", "Spontaneous Strain",
        "Peak Stress", "Critical Stress", "Dynamic Yield Strength", "Storage Modulus",
        "Yield Compressive Strength", "Ideal Tensile Strength", "Mechanical strength",
        "Adhesion strength", "Engineering Stress", "Strain-hardening rate",
        "Cleavage fracture", "Critical Load", "Strain-hardening Capability",
        "Dislocation Motion", "Void Growth", "Compression Fracture Strength",
        "Critical Twinning Stress", "Bending strength", "Compressive Flow Strength",
        "Interfacial Bonding Strength", "Solid-solution Strength", "Micro-Vickers Hardness",
        "Shear Resistance", "Strain Hardening Capability", "Softening resistance",
        "Shear strength", "Shear Elongation", "Residual stress", "Resilience",
        "Reduced Young's Modulus", "Internal Stress", "Elastic Stiffness",
        "Fretting Wear Resistance", "Strain Energy Density", "Compression Yield Stress",
        "Tensile Fracture Strength", "Stress Exponent", "Strain Hardening Rates",
        "Strain hardening exponent"
    ],
    "Thermal": [
        "Superconducting Transition Temperature", "Refrigeration Performance",
        "Liquidus temperature", "Thermal Resistance", "Grüneisen Parameter",
        "Latent Heat", "Adiabatic Temperature Variation", "Thermal Vacancy",
        "Coefficients of Thermal Expansion", "Volumetric heat capacity",
        "Barrier Failure Temperature", "Elastocaloric Temperature Change",
        "Reversible Isothermal Entropy Change", "Adiabatic Temperature Rise"
    ],
    "Electrical": [
        "ZT Value", "Electronic conductivity", "Hall Coefficients", "Dielectric Constant",
        "Electric Resistivity", "Electric resistivity", "Cationic Conductivity",
        "Metallic Conductivity", "Charge transfer resistance", "Electrochemical Impedance"
    ],
    "Magnetic": [
        "Magnetic entropy", "Magnetic Phase Transition Temperatures", "Magnetic Field",
        "Magnetization Change", "Magnetic Transition Temperatures", "Upper critical field",
        "Spontaneous Magnetization", "Maximum permeability", "Magnetic Ordering Temperature",
        "Magnetic susceptibility", "Magnetic-Entropy Change", "GMR Coefficient",
        "Exchange bias field", "Ferromagnetic to Paramagnetic Transformation Temperature",
        "Magnetic Remanence"
    ],
    "Chemical": [
        "Heats of Mixing", "Hydrogen Desorption Capacity", "Hydride Formation Enthalpy",
        "Hydrogen Resistance", "Hydride Equilibrium Pressure", "Transition Enthalpy",
        "Passivation current density", "Hydrogen Binding Energy", "Enthalpy of Mixing",
        "Desorption enthalpy", "Hydrogen Absorption Pressure", "Dehydriding Pressure",
        "Hydride formation enthalpy", "Oxidation States", "Hydrogen release-uptake",
        "Electrochemical activity"
    ],
    "Structural": [
        "Twin Density", "Theoretical Density", "Lattice constants",
        "Mean grain size", "Elemental Distributions", "Element Distribution",
        "Phase Transition Temperatures", "Grain Growth Resistance", "Transformation Entropy Change",
        "Dislocation density", "Atomic level stresses", "Phase Structures", "Stacking fault energy",
        "Phase Purity", "Crystal structures", "lattice parameters", "Phase content",
        "Martensitic Transformation Temperatures"
    ],
    "Surface": [
        "Infrared Emissivity", "Optical Transmittance", "Infrared Absorbance",
        "Surface Smoothness", "Passive Film Thickness", "TGO Growth Rate",
        "Protective Oxide Layer", "Passive films", "Oxygen Content"
    ],
    "Other Properties": [
        "Irradiation-tolerance", "Damage Accumulation", "CO2 Adsorption",
        "Fire Resistance", "Corrosion Resistances", "Corrosion potentials",
        "Corrosion current densities", "Corrosion Resistances", "Efficiency",
        "Dispersion", "Specific Capacitance", "Cryogenic Fracture Toughness",
        "Area Specific Resistance", "OER Catalytic Activity", "SRO",
        "Activation volume", "Aspect ratio", "Joint Strength", "Bending Modulus",
        "Bending Stiffness", "Specific Energy", "Diffusion Coefficients",
        "Dissipation Energy", "Stress Concentration", "Allen Electronegativity",
        "Recovery Strain", "Electrode porosity resistances", "CMAS resistance",
        "Bubble Density", "Loss Factor", "Weight Loss", "Slope Factor"
    ],
    "Unknown": [
        "H3/E2 Ratio", "E1/2", "phase", "Half-wave Potential", "Figure of merit",
        "(Hmix)", "Slope Factor", "Ordering Transition Temperature",
        "Double-layer capacitances", "Unstable Stacking Fault Energy",
        "Electro-negativity Difference", "Vibrational Density of States",
        "Valence-Electron Concentration", "Fragility Index", "Extinction Coefficient",
        "Absorption energy"
    ]
}

d9={
    "Mechanical": [
        "Shear Yield Strength", "Nano hardness", "Specific Yield Stress", "Breaking Strength",
        "Shear Yield Stress", "Impact Strength", "Compression Rate", "Yield Tensile Strength",
        "Plasticity Index", "Creep Strength", "Hugoniot Elastic Limit", "Plastic Deformation Resistance",
        "Cryogenic Toughness", "Hot Hardness", "Bulk Hardness", "Work-Hardening Exponent",
        "Compressive Strain to Failure", "Engineering Strain", "Shock Strength", "Stress Intensity Factor",
        "Strain Hardening Rate", "von Mises Stress", "Maximum Strength", "Fracture Strains",
        "Micro-compressive Plasticity", "Hardness (Vickers)", "Threshold Stress Intensity Factor Range",
        "Threshold Stress Range", "Strain-to-failure"
    ],
    "Thermal": [
        "Refrigerating Capacity", "Recrystallization Temperature", "Working Temperature Interval",
        "Thermal Fatigue Life", "Carrier Thermal Conductivity", "Low Temperature Specific Heat",
        "Temperature Coefficient of Resistance", "Adiabatic Temperature Change",
        "Coefficients of Thermal Expansion", "Thermal Emittance"
    ],
    "Electrical": [
        "Power Factor", "Hall Measurement", "Residual Resistivity Ratio", "Electronic Specific Heat",
        "Relative Permittivity", "Voltage", "Charge Transfer Rate"
    ],
    "Magnetic": [
        "Magnetic Permeability", "Magnetic Hysteresis", "Magnetic Entropy Variation",
        "Critical Field", "Magnetic Field Induced Entropy Changes", "Initial Permeability",
        "Effective Magnetic Moment", "Magnetic Transition Temperature Range",
        "Maximum Magnetic Entropy Change", "Magnetic-field-induced Entropy Change",
        "Magnetic Loss", "Saturation Induction", "Maximum Magnetic Flux Density",
        "Residual Magnetization", "Effective Permeability", "AC Susceptibility"
    ],
    "Chemical": [
        "Binding Energy", "Hydrogen Solubility", "Hydrogen Concentration", "Hydrogenation Kinetics",
        "Oxide Scales", "Oxidation Behaviour", "Repassivation Potential", "Corrosion Current",
        "Corrosion Current Density", "Bio-Corrosion Resistance", "Vacancy Formation Enthalpy",
        "Standard Enthalpy", "Enthalpy Change", "Reaction Rate", "Vacancy Concentration"
    ],
    "Structural": [
        "Grain Boundary Diffusivity", "Grain Sizes", "Grain Structures", "Lattice Volume",
        "Crystal System", "Space Groups", "Stack Fault Energy", "Phase Fractions",
        "Phase Fraction", "Phase Constituents", "Twin Boundary Density",
        "Intermetallics", "Intermetallic Phases", "Superlattice Structures",
        "Crystallographic Texture", "Generalized Stacking-Fault Energy", "Polycrystalline Elastic Moduli"
    ],
    "Surface": [
        "Contact Angle", "Wetting Angle", "Surface Composition", "Surface Activity",
        "RMS Roughness", "Friction Factor", "Friction Force", "Specific Wear Rate",
        "Frictional Wear Weight Loss", "Scratch Hardness"
    ],
    "Other Properties": [
        "Dissolution Rate", "Erosion Rate", "Erosion Wear Resistance", "Refrigerating Capacity",
        "Spalling Resistance", "DBTT", "Mass Transport", "Swelling Resistance",
        "Volumetric Swelling", "Swelling Resistance", "Cavity Density", "Cavity Size",
        "Density of States", "Partial Density of States", "Cluster Size", "Configuration Entropy",
        "Thermodynamic Parameters", "Atomic Radius", "Atomic Radii", "Atomic Size",
        "Atomic Size Differences", "Average Atomic Weight", "Allen's Electronegativity",
        "Pauling's Electronegativity", "Lattice Elastic Strain Energy", "Back Stress",
        "Anisotropy Ratio", "Anisotropy Index", "Effective Bandwidth", "Effective Absorption Bandwidth",
        "Electromagnetic Wave Absorption", "HER Performance", "OER Performances", "OER Performance",
        "Alkaline OER Performance", "Photocatalytic Activity", "Potential Differences",
        "Peak Potential", "Tafel Anode Slope", "Tafel Cathode Slope", "Polarization Resistance",
        "Protective Al2O3 Scale", "Protective Capacity", "Removal Torque", "Cycle Life",
        "Wear Loss", "Impact Energy Absorption Density", "Energy Consumption", "Lifetime",
        "Effective Elastic Modulus", "Elastic Storage Modulus", "Elastic Recovery Index",
        "Reversible Storage Capacity", "Effective Permeability", "Effective Absorption Bandwidth",
        "RC Value", "Density", "Total Density", "Linear Expansion Coefficient",
        "Hall Measurement", "Allen Electronegativity", "Potential Energy", "Kadowaki-Woods Ratio"
    ],
    "Unknown": [
        "Anelastic Internal Friction", "Void Nucleation Rate", "Dilution Rate", "Grain Boundary Strength",
        "Dislocation Velocity", "Dislocation Activities", "Interface Shear Resistance Force",
        "Self-Interstitial Formation Energy", "Grain Boundary Migration", "Nucleation Rate",
        "Micro Vickers Hardness", "N el Temperature", "MT Temperature", "Plateau Pressure",
        "Self-Corrosion Potential", "Lattice Elastic Strain Energy", "Shock Strength",
        "D-orbital Energy Level Parameter", "Rct", "S"
    ]
}

d10={
    "Mechanical": [
        "Compression Stress", "Intrinsic Strength", "Plastic Energy", "Bulk Elastic Modulus", 
        "Erosion Resistance", "Damage Resistance", "Charpy Impact Energy", "Transverse Strength", 
        "Ultimate Compressive Strength", "Rockwell Hardness", "Strain-to-Failure", "Fatigue Threshold", 
        "Fracture Stress", "Fatigue Crack Growth", "Plastic-Strain Limit", "Bonding Strength", 
        "Dynamic Shear Strength", "Cracking Resistance", "Ultimate Elongation", "Hardening Capacity", 
        "Impact-Resistance", "Yielding Strengths", "Stress Amplitude", "Work Hardening Rates", 
        "Compressive Yield Strengths", "Compressive Yield Stress", "Friction Strength", "Threshold Stress", 
        "Tensile Strengths", "Strength-to-Weight Ratio", "Macroscopic Hardness", "Microscopic Hardness", 
        "Martens Hardness", "Creep Stress", "Vickers Indentation Fracture Toughness", "Vickers' Micro-Hardness"
    ],
    "Thermal": [
        "Melting Enthalpy", "Temperature Coefficients of Expansion", "Thermal Vacancy Concentrations", 
        "Decomposition Temperature", "Thermal Fatigue", "Thermal Hysteresis Loss", "Processing Temperature", 
        "Thermal Emissivity", "Thermal-Oxidative Resistance", "Phase Change Temperature"
    ],
    "Electrical": [
        "Dielectric Constants", "Bandgap", "Energy Gap", "Electron Conductivity", "Electrical Transition Temperature", 
        "Metal-Insulator Transition", "Dielectric Losses", "Work Function", "Contact Resistance"
    ],
    "Magnetic": [
        "B_s", "H_c", "Flux Density", "Metamagnetic Transition Temperature", "Magnetocaloric Performance", 
        "Intrinsic Coercivity", "Coercive Fields", "Magnetoresistance Ratio", "Local Magnetic Moments", 
        "Remanence Ratio", "Magnetic Losses", "Magnetic Hysteresis Loss", "Magnetic Phase Transition Temperatures", 
        "Metamagnetic Phase Transition Temperature", "Magnetic Viscosity"
    ],
    "Chemical": [
        "Pitting Corrosion Resistance", "Oxidation Wear Resistance", "Primary Passivation Potential", 
        "Secondary Passivation Potential", "Hydrogen Embrittlement Susceptibility", "Erosion-Corrosion Resistance", 
        "Hydrogen Evolution Performance", "Hydrogen Desorption Rate", "Electrochemical Corrosion Resistance", 
        "Salt Corrosion Resistance", "Electrochemical Surface Area", "Hydrogenation Enthalpy", "Hydrogenation Entropy", 
        "Electrochemical Impedance", "Electrochemical Kinetics", "HER Overpotential", "Electrochemical Full Capacity", 
        "Oxygen Evolution Activity", "Electrochemical Kinetics", "Reaction Activity", "Methanol Tolerance", 
        "Anodic Current Density", "Passive Region Width", "Protection Potential", "Hydrogen Content", 
        "Electrochemical Impedance", "Adsorption Energy", "Adsorption Energies", "Catalytic Efficiency", 
        "Electrochemical Corrosion Resistance", "Antioxidant Performance", "Phase-Specific Hardness", 
        "Solubility Limit", "Solubility"
    ],
    "Structural": [
        "Mean-Square Atomic Displacements", "Mean Square Atomic Displacement", "Grain Diameter", "Grain Growth Rate", 
        "Lattice Friction", "Lattice Spacing", "Lattice Structure", "Lattice Structures", "HCP Phase Content", 
        "HCP Phase Fraction", "Phase Transformation Temperatures", "Phase Change Temperature", "Phase Fractions", 
        "Phase Compositions", "Phase Constitution", "Phase Content", "Equilibrium Phase Fraction", 
        "Volume Fraction of Phase", "Phase Transition Temperature", "A2 Phase Amount", "A2 Phase Size", 
        "Phase Transition Temperatures", "Core/Shell Structure", "Crystallographic Orientation", "Microstructure"
    ],
    "Surface": [
        "Frictional Coefficient", "Nanoscratch Resistance", "Normal Force", "Water Contact Angle", 
        "Contact Angles", "Surface Reaction Exchange Current", "Surface Structure", "Interface Strength"
    ],
    "Other Properties": [
        "Energy Barrier", "EOS", "Free Volume Content", "Peak Area", "Atomic Displacement Parameter", 
        "Damping Capability", "Nitrogen Content", "Entropy of Mixing", "Mass Gains", "Geometrical Parameter", 
        "Cooling Efficiency", "Dynamic Compression", "Absorption Energy", "Double-Layer Capacitance", 
        "Defect Size", "Decoloration Rate", "Fretting Resistance", "Zener Anisotropy Ratio", "Energy Product", 
        "Coarsening Kinetics", "Bulk Sound Speed", "Dilatational Strain", "Poisson's Ratios", "Poisson's Coefficient", 
        "Poisson's Ratios", "Serrated Plastic Flow", "Wave Speed", "P Content", "Operating Temperature", 
        "Change of Entropy", "Energy Absorption", "Cooling Temperature Difference", "Recrystallization Fraction", 
        "Absorption Bandwidth", "Detection Range", "Detection Limit", "MOR Peak Current Density", 
        "Activation Time", "Energy Density", "Mass Transfer Paths", "Initial Contact Pressure", "Complex Modulus", 
        "Specific Power", "Ionic Diffusion Mobility", "Cycle Lives", "Phase Transition Enthalpy", 
        "Volumetric Energy Storage Capacity", "Solar Absorptivity", "ZT Value", "Defect Concentration", 
        "Burgers Vector", "Percent Loss of Elongation", "Defect Counts", "Mean Atomic Radius", "Wigner Seitz Radius"
    ],
    "Unknown": [
        "Plateau Hysteresis", "Saturation Rate", "Film Stress", "Loss Modulus", "Barrier Strength", 
        "Strain Amplitude", "Molar Volume Change", "Light Absorbance", "Linear Attenuation Coefficient", 
        "PCT Plateau Pressure", "Slurry Erosion Rate", "Raman Peaks", "Nominal Shear Stress", "Solid-Solution Strength", 
        "Sulfidation Resistance", "Anisotropy Parameter"
    ]
}

# %%
from collections import defaultdict

D=[d1,d2,d3,d4,d5,d6,d7,d8,d9,d10]
property_list=defaultdict(list)

for d in D:
    for k,v in d.items():
        property_list[k].extend(v)

property_dictionary=dict(property_list)

# print(property_dictionary['Electrical'])
# print(property_dictionary['Magnetic'])
#print(property_dictionary['Chemical'])
# print(property_dictionary['Structural'])
# print(property_dictionary['Surface'])
print(property_dictionary['Unknown'])
# Out:
# ['Discharge Capacity', 'Radiation Resistance', 'Diffusion', 'Hydrogen Storage Capacity', 'Hydrogen Capacity', 'Diffusivity', 'Composition', 'Chemical Composition', 'Erosion Resistance', 'Radiation Tolerance', 'Wetting', 'Adiabatic Bulk Modulus', 'Tm', 'Ms', 'VEC', 'Tl', 'Tx', 'S', 'Volume Fraction', 'Atomic Size Difference', 'UE', 'MA Loss', 'Figure-of-Merit', 'Effective Mass', 'Zener Ratio', 'Dislocation-core Diffusion', 'Indentation-energy factor', 'Dislocation width', 'Resistance to Shear Localization', 'Effective Refrigerant Capacities', 'Gibbs free energy', 'TL', 'Coefficient of Performance', 'Helmholtz Free Energy', 'Twin Strength', 'Spallation Resistance', 'Volume Wear Rate', 'CMAS Resistance', 'Mass transfer rate', 'Bio-corrosion Resistance', 'H Species Adsorption', 'Sommerfeld Coefficient', 'Volume change', 'Radiation Damage', 'Radiation damage', 'H3/E2 Ratio', 'E1/2', 'phase', 'Half-wave Potential', 'Figure of merit', '(Hmix)', 'Slope Factor', 'Ordering Transition Temperatu
# ...

# %%
import csv
data = property_dictionary
csv_filename = "properties.csv"
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Property", "Category"])
    for category, properties in data.items():
        for prop in properties:
            writer.writerow([prop, category])

# with open(csv_filename,'r') as f:
#     reader=csv.reader(f)
    
#     head=next(reader)
#     print(head)

#     for row in reader:
#         print(row)

# %%
mechanical_properties_dict = {
    "Hardness": ["Hardness", "Microhardness", "Nanohardness", "Vickers microhardness", "Vickers Micro-Hardness",
                 "Rockwell Hardness", "Macrohardness", "Micro-Vickers Hardness", "Martens Hardness",
                 "Bulk Hardness", "Microscopic Hardness", "Macroscopic Hardness", "Intrinsic Hardness",
                 "Mechanical Hardness", "Micro Hardness", "Nano Hardness", "Nano-hardness",
                 "Nano-Hardness", "Micro-hardness", "Micro Vickers hardness", "Hardness (Vickers)",
                 "Vickers' Micro-Hardness", "Vickers Indentation Fracture Toughness"],
    "Ductility": ["Ductility", "Tensile Ductility", "Bending Ductility", "Compressive Ductility"],
    "Yield Strength": ["Yield Strength", "Yield Stress", "Tensile Yield Stress", "Specific Yield Strength",
                       "Yielding Strength", "Yielding Strengths", "Yield Compressive Strength", "Yield Strain",
                       "Specific Yield Stress", "Yield Tensile Strength", "Compressive Yield Strength",
                       "Compressive Yield Strengths", "Compressive Yield Stress", "Compression Yield Strength",
                       "Compressive Yield Stress", "Yield Strengths"],
    "Ultimate Tensile Strength": ["Ultimate Tensile Strength", "UTS", "Ultimate Strength",
                                   "Ultimate tensile stress", "Tensile Strength", "Tensile Strengths",
                                   "Ultimate Tensile Elongation", "Ultimate Elongation"],
    "Compressive Strength": ["Compressive Strength", "Compressive Ultimate Strength",
                             "Ultimate Compressive Strength", "Compression Strength",
                             "Compression Stress", "Compression Yield Strength",
                             "Compressive Fracture Strength"],
    "Wear Resistance": ["Wear Resistance", "Wear", "Wear-Resistance", "Wear rate", "Wear Rates",
                        "Wear Rate", "Wear Volume", "Abrasive Wear Resistance", "Fretting Wear Resistance",
                        "Cavitation Erosion Resistance", "Erosion Resistance"],
    "Toughness": ["Toughness", "Fracture Toughness", "Impact Toughness", "Fracture Resistance",
                  "Cryogenic Toughness", "Impact Strength", "Impact Resistance", "Fracture Energy",
                  "Charpy Impact Energy", "Hardening Capacity"],
    "Elastic Modulus": ["Elastic Modulus", "Young's Modulus", "Young modulus", "Young s Modulus",
                        "Reduced Young's Modulus", "Modulus of Elasticity", "Elastic Moduli",
                        "Bulk Modulus", "Bulk Moduli", "Bulk Elastic Modulus", "Elastic Constants",
                        "Elastic Stiffness", "Indentation Modulus", "Indentation Moduli",
                        "Storage Modulus"],
    "Shear Strength": ["Shear Strength", "Shear Modulus", "Shear Stress", "Shear Yield Strength",
                       "Shear Yield Stress", "Shear Resistance", "Ultimate Shear Strength",
                       "Critical Resolved Shear Stress", "Shear Deformation", "Shear Elongation"],
    "Strain": ["Strain", "Total Strain", "Plastic Strain", "Fracture Strain", "Fracture Elongation",
               "Strain to Failure", "Strain-to-failure", "Tensile Strain", "Elastic Strain Energy",
               "Elastic Elongation", "Elastic Strain Limit", "Plastic Strain to Failure",
               "Plastic-Strain Limit", "Strain Hardening Rate", "Strain Hardening Exponent",
               "Strain Hardening Rates", "Strain-Hardening Rate", "Strain Hardening Capability",
               "Strain-hardening rate", "Strain-hardening Rate", "Strain-hardening Capability",
               "Strain Rate", "Strain Energy Density", "Compressive Strain", "Compression Strain",
               "True Strain", "Ultimate Strain", "Strain Hardening Coefficient"],
    "Stress": ["Stress", "Maximum Stress", "Flow Stress", "Fracture Stress", "True Stress",
               "von Mises Stress", "Engineering Stress", "Tensile Stress", "Compressive Stress",
               "Dynamic Yield Strength", "Critical Stress", "Peak Stress", "Stress Intensity Factor",
               "Threshold Stress", "Threshold Stress Intensity Factor", "Threshold Stress Intensity Factor Range",
               "Threshold Stress Range", "Stress Amplitude", "Stress Exponent"],
    "Fatigue": ["Fatigue", "Fatigue Resistance", "Fatigue Life", "Fatigue Strength",
                "Fatigue Limit", "Fatigue Threshold", "Fatigue Crack Growth", "Cyclic Fatigue Resistance"],
    "Creep": ["Creep", "Creep Resistance", "Creep Strength", "Creep Rate", "Creep Stress",
              "Creep Exponent", "Steady-State Flow"],
    "Friction": ["Friction Coefficient", "Coefficient of Friction", "Friction Resistance",
                 "Friction Stress", "Friction Strength"],
    "Compression": ["Compression Strength", "Compression Yield Strength", "Compression Stress",
                    "Compression Fracture Strength", "Compression Strain", "Compression Ratio",
                    "Compression Rate", "Compression performance"],
    "Work Hardening": ["Work Hardening Rate", "Work-Hardening Rate", "Work-Hardening Capacity",
                       "Work Hardening Capacity", "Work Hardening Rates", "Work-Hardening Exponent"],
    "Residual Stress": ["Residual Stress", "Residual Stresses", "Internal Stress"],
    "Poisson's Ratio": ["Poisson's Ratio", "Poisson s Ratio"],
    "Brittleness": ["Brittleness", "Brittleness Index"],
    "Bonding Strength": ["Bonding Strength", "Interfacial Bonding Strength", "Adhesive Strength",
                         "Adhesion Strength"],
    "Yield Stress": ["Yield Stress", "Yielding Strength", "Yielding Strengths"],
    "Stiffness": ["Stiffness", "Elastic Stiffness"],
    "Specific Strength": ["Specific Strength", "Specific Yield Strength", "Specific Compressive Strength"],
    "Fracture": ["Fracture", "Fracture Stress", "Fracture Strength", "Fracture Toughness",
                 "Fracture Strain", "Fracture Energy", "Fracture Resistance", "Fracture Elongation",
                 "Fracture Strains", "Fracture Stress"],
    "Damping Capacity": ["Damping Capacity", "Shock Strength"],
    "Deformation Resistance": ["Deformation Resistance", "Plastic Deformation Resistance"],
    "Strength-to-Weight Ratio": ["Strength-to-Weight Ratio"],
    "Damage Resistance": ["Damage Resistance"],
    "Hall-Petch Coefficient": ["Hall-Petch Coefficient"],
    "Pugh's Ratio": ["Pugh s ratio"],
    "Dislocation Density": ["Dislocation Density"],
    "Solid-Solution Strength": ["Solid-Solution Strength"],
    "Indentation Hardness": ["Nanoindentation Hardness"],
    "Internal Friction": ["Internal Friction"],
    "Twinning Stress": ["Twinning Stress", "Critical Twinning Stress"],
    "Cleavage Fracture": ["Cleavage Fracture"],
    "Rupture Strain": ["Rupture Strain"],
    "Dislocation Motion": ["Dislocation Motion"],
    "Void Growth": ["Void Growth"],
    "Cohesive Strength": ["Cohesive Strength"],
    "Engineering Strain": ["Engineering Strain"],
    "Spall Strength": ["Spall Strength"],
    "Cutting Force": ["Cutting Force"],
    "Energy Absorption Capacity": ["Energy Absorption Capacity"],
    "Compression Performance": ["Compression Performance"],
    "Intrinsic Strength": ["Intrinsic Strength"]
}

# %%
thermal_properties_dict = {
    "Thermal Conductivity": ["Thermal Conductivity", "Thermal conductivity", "High Thermal Conductivity", "Lattice Thermal Conductivity", "Carrier Thermal Conductivity"],
    "Curie Temperature": ["Curie Temperature", "Curie Temperatures"],
    "Seebeck Coefficient": ["Seebeck Coefficient", "Thermopower"],
    "Heat Capacity": ["Heat Capacity", "Specific Heat", "Specific Heat Capacity", "Volumetric Heat Capacity", "Low Temperature Specific Heat"],
    "Thermal Diffusivity": ["Thermal Diffusivity", "Thermal diffusion coefficient", "Thermal Diffusion Coefficient"],
    "Melting Point": ["Melting Point", "Melting Temperature", "Melting temperature"],
    "Thermal Expansion Coefficient": ["Thermal Expansion Coefficient", "Coefficient of Thermal Expansion", "Thermal Expansion Coefficients", "Linear Thermal Expansivity", "TEC", "CTE", "Temperature Coefficient of Resistance", "Temperature Coefficients of Expansion", "Coefficients of Thermal Expansion"],
    "Thermal Expansion": ["Thermal Expansion", "Volumetric Thermal Expansion"],
    "Relative Cooling Power": ["Relative Cooling Power", "Cooling Power"],
    "Ductile Brittle Transition Temperature": ["Ductile Brittle Transition Temperature"],
    "Adiabatic Temperature Change": ["Adiabatic Temperature Change", "Adiabatic Temperature Variation", "Adiabatic Temperature Rise"],
    "Characteristic Temperatures": ["Characteristic Temperatures"],
    "Crystallization Temperature": ["Crystallization Temperature"],
    "Glass Transition Temperature": ["Glass Transition Temperature"],
    "Debye Temperature": ["Debye Temperature", "Debye temperature"],
    "Thermal Resistance": ["Thermal Resistance", "Heat Resistance", "Temperature Resistance"],
    "Refrigeration Capacity": ["Refrigeration Capacity", "Refrigerating Capacity", "Refrigeration Performance"],
    "Liquidus Temperature": ["Liquidus Temperature", "Liquidus temperature"],
    "Transformation Temperatures": ["Transformation Temperatures", "Phase Transformation Entropy", "Phase Transition Temperature", "Phase Change Temperature"],
    "Solidus Temperature": ["Solidus Temperature", "Solidus temperature"],
    "Softening Coefficient": ["Softening Coefficient", "High Temperature Softening Resistance", "Thermal Softening Resistance"],
    "Working Temperature Range": ["Working Temperature Range", "Temperature Range", "Working Temperature Window", "Service Temperature", "Working Temperature Interval"],
    "Isothermal Entropy Change": ["Isothermal Entropy Change", "Reversible Isothermal Entropy Change"],
    "Pasty Range": ["Pasty Range"],
    "Grüneisen Coefficient": ["Grüneisen Coefficient", "Grüneisen Parameter", "Gr neisen Coefficient"],
    "Cutting Temperature": ["Cutting Temperature"],
    "Cooling Rate": ["Cooling Rate"],
    "Superconducting Transition Temperature": ["Superconducting Transition Temperature"],
    "Latent Heat": ["Latent Heat", "Melting Enthalpy"],
    "Thermal Vacancy": ["Thermal Vacancy", "Thermal Vacancy Concentrations"],
    "Barrier Failure Temperature": ["Barrier Failure Temperature"],
    "Elastocaloric Temperature Change": ["Elastocaloric Temperature Change"],
    "Recrystallization Temperature": ["Recrystallization Temperature"],
    "Thermal Fatigue": ["Thermal Fatigue", "Thermal Fatigue Life"],
    "Thermal Hysteresis": ["Thermal Hysteresis", "Thermal Hysteresis Loss"],
    "Processing Temperature": ["Processing Temperature"],
    "Thermal Emissivity": ["Thermal Emissivity", "Thermal Emittance"],
    "Thermal-Oxidative Resistance": ["Thermal-Oxidative Resistance"],
    "Decomposition Temperature": ["Decomposition Temperature"]
}

# %%
electrical_properties_dict = {
    "Electrical Conductivity": ["Electrical Conductivity", "Conductivity", "Electronic Conductivity", "Electron Conductivity", "Metallic Conductivity"],
    "Resistivity": ["Resistivity", "Electrical Resistivity", "Electric Resistivity", "Electric resistivity", "Temperature Coefficient of Resistivity"],
    "Superconductivity": ["Superconductivity"],
    "Power Factor": ["Power Factor"],
    "Carrier Concentration": ["Carrier Concentration", "Hall Carrier Concentration", "Hole Concentration"],
    "Carrier Mobility": ["Carrier Mobility", "Hall Mobility", "Hall Carrier Mobility"],
    "Seebeck Coefficient": ["Seebeck Coefficient", "Seebeck Coefficients"],
    "Current Density": ["Current Density", "Critical Current Density", "Critical current density"],
    "Figure of Merit": ["Figure of Merit", "Figure-of-Merit", "Thermoelectric Figure of Merit", "ZT Value", "zT"],
    "Capacitance": ["Capacitance"],
    "Permittivity": ["Permittivity", "Relative Permittivity", "Complex Permittivity"],
    "Charge Transfer Impedance": ["Charge Transfer Impedance"],
    "Band Gap": ["Band Gap", "Band gap", "Bandgap", "Energy Gap"],
    "Hall Coefficient": ["Hall Coefficient", "Hall Coefficients"],
    "DOS Effective Mass": ["DOS Effective Mass"],
    "Breakdown Potential": ["Breakdown Potential"],
    "Work Function": ["Work Function"],
    "Dielectric Constant": ["Dielectric Constant", "Dielectric Constants"],
    "Ionic Conductivity": ["Ionic Conductivity", "Cationic Conductivity"],
    "Electrical Resistance": ["Electrical Resistance", "Electrical resistance"],
    "Discharge Potential": ["Discharge Potential"],
    "Thermoelectric Performance": ["Thermoelectric Performance"],
    "Electronic Thermal Conductivity": ["Electronic Thermal Conductivity", "Electronic thermal conductivity"],
    "Charge Transfer": ["Charge Transfer", "Charge Transfer Rate"],
    "Attenuation Constant": ["Attenuation Constant"],
    "Electron Mean Free Path": ["Electron Mean Free Path"],
    "Dielectric Loss": ["Dielectric Loss", "Dielectric Losses"],
    "Cell Voltage": ["Cell Voltage"],
    "Charge Transfer Resistance": ["Charge Transfer Resistance"],
    "Electrochemical Impedance": ["Electrochemical Impedance"],
    "Hall Measurement": ["Hall Measurement"],
    "Residual Resistivity Ratio": ["Residual Resistivity Ratio"],
    "Electronic Specific Heat": ["Electronic Specific Heat"],
    "Voltage": ["Voltage"],
    "Electrical Transition Temperature": ["Electrical Transition Temperature"],
    "Metal-Insulator Transition": ["Metal-Insulator Transition"],
    "Contact Resistance": ["Contact Resistance"]
}

# %%
magnetic_properties_dict = {
    "Magnetization": ["Magnetization", "Magnetisation", "Magnetization Change", "Residual Magnetization", "Spontaneous Magnetization"],
    "Magnetic Entropy Change": ["Magnetic Entropy Change", "Magnetic Entropy Changes", "Magnetic-Entropy Change", "Isothermal Magnetic Entropy Change", "Magnetic Field Induced Entropy Changes", "Magnetic Entropy Variation", "Maximum Magnetic Entropy Change", "Magnetic-field-induced Entropy Change"],
    "Coercivity": ["Coercivity", "Coercive Force", "Coercive field", "Coercive Field", "AC Coercivity", "Intrinsic Coercivity", "Coercive Fields", "H_c", "Hc"],
    "Magnetocaloric Effect": ["Magnetocaloric Effect", "Magnetocaloric", "Magnetocaloric Properties", "Magnetocaloric Response", "Magnetocaloric Performance"],
    "Saturation Magnetization": ["Saturation Magnetization", "Saturated Magnetization", "Saturation magnetisation", "Magnetic Saturation"],
    "Curie Temperature": ["Curie Temperature", "Curie Point", "Ferromagnetic to Paramagnetic Transformation Temperature", "Magnetic Ordering Temperature"],
    "Hysteresis": ["Hysteresis", "Magnetic Hysteresis", "Hysteresis Loss", "Hysteresis Losses", "Hysteresis losses", "Magnetic Hysteresis Loss"],
    "Magnetic Entropy": ["Magnetic Entropy", "Magnetic entropy", "Magnetic Entropy Variation"],
    "Magnetoresistance": ["Magnetoresistance", "Magnetoresistance Ratio", "GMR Coefficient"],
    "Magnetic Moment": ["Magnetic Moment", "Magnetic Moments", "Local Magnetic Moments", "Effective Magnetic Moment"],
    "Magnetic Susceptibility": ["Magnetic Susceptibility", "Magnetic susceptibility", "Susceptibility", "AC Susceptibility"],
    "Magnetism": ["Magnetism", "Static Magnetism", "Ferromagnetism"],
    "Magnetostriction": ["Magnetostriction", "Magnetostriction Coefficient", "Magnetostrain", "Magnetic-Field-Induced Strain"],
    "Remanence": ["Remanence", "Magnetic Remanence", "Remanence Ratio"],
    "Magnetic Transition Temperature": ["Magnetic Transition Temperature", "Magnetic Transition Temperatures", "Magnetic Phase Transition Temperatures", "Metamagnetic Transition Temperature", "Metamagnetic Phase Transition Temperature", "Magnetic Transition Temperature Range"],
    "Upper Critical Field": ["Upper Critical Field", "Upper Critical Fields"],
    "Exchange Bias Field": ["Exchange Bias Field", "Exchange bias field"],
    "Magnetic Permeability": ["Magnetic Permeability", "Effective Permeability", "Effective Magnetic Moment", "Maximum Permeability", "Initial Permeability"],
    "EM Absorption Performance": ["EM Absorption Performance"],
    "Saturation Magnetic Flux Density": ["Saturation Magnetic Flux Density", "Maximum Magnetic Flux Density", "Saturation Induction", "Flux Density", "B_s"],
    "Magnetic Field": ["Magnetic Field"],
    "Critical Field": ["Critical Field"],
    "Core Loss": ["Core Loss"],
    "Eddy Current Loss": ["Eddy Current Loss"],
    "Magnetic Loss": ["Magnetic Loss", "Magnetic Losses"],
    "Magnetic Softness": ["Magnetic Softness"],
    "Magnetic Viscosity": ["Magnetic Viscosity"],
    "Charge Transfer": ["Charge Transfer"]
}

# %%
chemical_properties_dict = {
    "Catalytic Activity": ["Catalytic Activity", "Electrocatalytic Activity", "Catalytic Performance", "Electrochemical Activity", "Catalytic Efficiency", "Reaction Activity"],
    "Electronegativity": ["Electronegativity", "Electronegativity Difference"],
    "Overpotential": ["Overpotential", "Overpotentials", "HER Overpotential"],
    "Mixing Entropy": ["Mixing Entropy", "Smix"],
    "Pitting Potential": ["Pitting Potential", "Repassivation Potential", "Primary Passivation Potential", "Secondary Passivation Potential"],
    "Mixing Enthalpy": ["Mixing Enthalpy", "Hmix", "Enthalpy of Mixing", "Heats of Mixing"],
    "Oxidation Behavior": ["Oxidation Behavior", "Oxidation Behaviour", "Oxidation Rate", "Oxidation Kinetics", "Oxidation Wear Resistance"],
    "Oxidation Resistance": ["Oxidation Resistance", "Oxide Scales"],
    "Passivation": ["Passivation", "Passive Current Density", "Passivation Current Density", "Passive Region Width"],
    "Pitting Corrosion Resistance": ["Pitting Corrosion Resistance", "Pitting Corrosion", "Local Corrosion Resistance"],
    "ORR Activity": ["ORR Activity", "Oxygen Evolution Activity"],
    "OER Activity": ["OER Activity"],
    "Corrosion Potential": ["Corrosion Potential", "Protection Potential"],
    "Tafel Slope": ["Tafel Slope"],
    "HER Activity": ["HER Activity", "Hydrogen Evolution Performance", "Hydrogen Evolution Kinetics"],
    "Corrosion Current Density": ["Corrosion Current Density", "Corrosion Current", "Exchange Current Density", "Anodic Current Density"],
    "MOR Activity": ["MOR Activity", "MOR Onset Potential", "Methanol Tolerance"],
    "Corrosion Rate": ["Corrosion Rate", "Corrosion Parameters"],
    "Dehydrogenation Enthalpy": ["Dehydrogenation Enthalpy", "Hydrogenation Enthalpy"],
    "CO Poisoning Tolerance": ["CO Poisoning Tolerance", "Poisoning Resistance", "Resistance to CO Poisoning", "CO Stripping Peak", "Methanol Adsorption Energy"],
    "Hydrogen Embrittlement Resistance": ["Hydrogen Embrittlement Resistance", "Hydrogen Embrittlement Susceptibility"],
    "Hydrogen Absorption Capacity": ["Hydrogen Absorption Capacity", "Hydrogen absorption capacity", "Hydrogen Solubility", "Hydrogen Content", "Hydrogen Concentration"],
    "Charge Transfer Resistance": ["Charge Transfer Resistance"],
    "Reaction Kinetics": ["Reaction Kinetics", "Reaction Rate", "Electrochemical Kinetics", "Electrochemical Durability"],
    "Activation Energy": ["Activation Energy"],
    "Redox Peak Potentials": ["Redox Peak Potentials"],
    "Free Energy": ["Free Energy"],
    "Tribocorrosion Resistance": ["Tribocorrosion Resistance", "Erosion-Corrosion Resistance"],
    "Electrochemical Corrosion Resistance": ["Electrochemical Corrosion Resistance", "Salt Corrosion Resistance", "Bio-Corrosion Resistance"],
    "Electrochemical Surface Area": ["Electrochemical Surface Area"],
    "Electrochemical Impedance": ["Electrochemical Impedance"],
    "Electrochemical Full Capacity": ["Electrochemical Full Capacity"],
    "Hydrogenation Entropy": ["Hydrogenation Entropy", "Dehydrogenation Entropy"],
    "Bond Strength": ["Bond Strength", "Metal-H Bond Strength"],
    "Formation Enthalpy": ["Formation Enthalpy", "Standard Enthalpy", "Enthalpy Change", "Transition Enthalpy"],
    "Hydrogen Permeability": ["Hydrogen Permeability"],
    "Hydrogen Adsorption Impedance": ["Hydrogen Adsorption Impedance"],
    "H Pick-up": ["H Pick-up"],
    "Formation Energy": ["Formation Energy"],
    "Dissociation Pressure": ["Dissociation Pressure", "Hydride Equilibrium Pressure", "Dehydriding Pressure"],
    "Cytotoxicity": ["Cytotoxicity"],
    "Hydrogen Desorption Capacity": ["Hydrogen Desorption Capacity", "Hydrogen Release-Uptake", "Hydrogen Desorption Rate"],
    "Hydride Formation Enthalpy": ["Hydride Formation Enthalpy", "Hydride formation enthalpy"],
    "Hydrogen Resistance": ["Hydrogen Resistance"],
    "Hydrogen Binding Energy": ["Hydrogen Binding Energy"],
    "Adsorption Energy": ["Adsorption Energy", "Adsorption Energies", "Oxygen Adsorption Energy"],
    "Hydrogenation Kinetics": ["Hydrogenation Kinetics"],
    "Vacancy Formation Enthalpy": ["Vacancy Formation Enthalpy"],
    "Vacancy Concentration": ["Vacancy Concentration"],
    "Standard Enthalpy": ["Standard Enthalpy"],
    "Antioxidant Performance": ["Antioxidant Performance"],
    "Phase-Specific Hardness": ["Phase-Specific Hardness"],
    "Solubility Limit": ["Solubility Limit", "Solubility"],
}

# %%
structural_properties_dict = {
    "Glass Forming Ability": ["Glass Forming Ability", "Glass-Forming Ability", "GFA"],
    "Stacking Fault Energy": ["Stacking Fault Energy", "SFE", "Stack Fault Energy", "Generalized Stacking-Fault Energy"],
    "Crystal Structure": ["Crystal Structure", "Crystal Structures", "Crystal System", "Room Temperature Crystal Structure"],
    "Lattice Parameter": ["Lattice Parameter", "Lattice Parameters", "Lattice Constant", "Lattice Constants", "Lattice Structure", "Lattice Structures", "Lattice Spacing"],
    "Phase Composition": ["Phase Composition", "Phases", "Phase Constituents", "Phase Compositions", "Phase Structures", "Phase Structure", "Phase Constitution", "Phase Content", "Phase Purity"],
    "Phase Fractions": ["Phase Fractions", "Phase Fraction", "Equilibrium Phase Fraction", "Volume Fraction of Phase", "Volume Fractions", "Volume Fraction"],
    "Phase Transition Temperature": ["Phase Transition Temperature", "Phase Transition Temperatures", "Phase Transformation Temperatures", "Phase Change Temperature"],
    "Martensitic Transformation Temperature": ["Martensitic Transformation Temperature", "Martensitic Transformation Temperatures"],
    "Unit Cell Volume": ["Unit Cell Volume", "Lattice Volume"],
    "Lattice Strain": ["Lattice Strain", "Lattice Distortion"],
    "Lattice Friction": ["Lattice Friction", "Lattice Friction Stress"],
    "Interstitial Content": ["Interstitial Content"],
    "Vacancy Formation Energy": ["Vacancy Formation Energy", "Formation Energy"],
    "Grain Boundary Energy": ["Grain Boundary Energy", "Grain Boundary Diffusivity"],
    "Grain Structure": ["Grain Structure", "Grain Structures", "Grain Sizes", "Grain Growth Kinetics", "Grain Growth Rate", "Grain Growth Resistance"],
    "Grain Size": ["Grain Size", "Average Grain Size", "Mean Grain Size", "Grain Diameter"],
    "Twin Density": ["Twin Density", "Twin Fault Probability", "Twin Boundary Density"],
    "Phase Transition": ["Phase Transition Temperatures", "Phase Transformation Temperatures"],
    "Elemental Distribution": ["Elemental Distribution", "Elemental Distributions", "Element Distribution"],
    "Short-range Order": ["Short-range Order"],
    "Dislocation Density": ["Dislocation Density"],
    "Atomic Level Stresses": ["Atomic Level Stresses"],
    "Point Defects": ["Point Defects"],
    "Lamellar Widths": ["Lamellar Widths"],
    "Atomic Radius": ["Atomic Radius"],
    "Elemental Composition": ["Elemental Composition"],
    "Elastic Constant": ["Elastic Constant"],
    "True Strain": ["True Strain"],
    "Threshold Displacement Energy": ["Threshold Displacement Energy"],
    "Cohesive Energies": ["Cohesive Energies"],
    "Elastic Moduli": ["Elastic Moduli", "Polycrystalline Elastic Moduli", "Polycrystalline Elastic Modulus"],
    "Sound Velocities": ["Sound Velocities"],
    "Pugh Ratio": ["Pugh Ratio"],
    "Interfacial Energy": ["Interfacial Energy"],
    "Crack-Growth Rates": ["Crack-Growth Rates"],
    "Crystallization Kinetics": ["Crystallization Kinetics"],
    "Relative Density": ["Relative Density"],
    "Mass Density": ["Mass Density", "Theoretical Density"],
    "Structural Transformation": ["Structural Transformation"],
    "Phase Transition Temperatures": ["Phase Transition Temperatures"],
    "Transformation Entropy Change": ["Transformation Entropy Change"],
    "Crystallographic Texture": ["Crystallographic Texture"],
    "Crystallographic Orientation": ["Crystallographic Orientation"],
    "Crystallinity": ["Crystallinity"],
    "Crystallite Size": ["Crystallite Size"],
    "Lattice Constants": ["Lattice Constants", "Lattice parameters", "Lattice Parameter", "Lattice Spacing"],
    "Mean-Square Atomic Displacements": ["Mean-Square Atomic Displacements", "Mean Square Atomic Displacement"],
    "Phase Fractions": ["Phase Fractions", "Phase Fraction"],
    "Intermetallics": ["Intermetallics", "Intermetallic Phases"],
    "Superlattice Structures": ["Superlattice Structures"],
    "Space Groups": ["Space Groups"],
    "Core/Shell Structure": ["Core/Shell Structure"],
    "Microstructure": ["Microstructure"],
    "A2 Phase Amount": ["A2 Phase Amount"],
    "A2 Phase Size": ["A2 Phase Size"],
    "HCP Phase Content": ["HCP Phase Content", "HCP Phase Fraction"],
    "Wall Thickness": ["Wall Thickness"],
}

# %%
surface_properties_dict = {
    "Surface Area": ["Surface Area", "Specific Surface Area", "Effective Surface Area", "SA", "ECSA"],
    "Surface Roughness": ["Surface Roughness", "Roughness", "RMS Roughness", "Surface Smoothness"],
    "Friction": ["Friction", "Coefficient of Friction", "Friction Factor", "Friction Force", "Frictional Wear Weight Loss", "Frictional Coefficient"],
    "Adhesion": ["Adhesion", "Adhesion Strength"],
    "Surface Energy": ["Surface Energy", "Surface Energies", "Surface Fracture Energy"],
    "Wear Resistance": ["Wear Volume", "Specific Wear Rate", "Nanoscratch Resistance", "Scratch Hardness"],
    "Hardness": ["Surface Hardness", "Indentation Hardness", "Scratch Hardness"],
    "Pitting Resistance": ["Pitting Resistance", "Pitting Corrosion Potential"],
    "Contact Angle": ["Contact Angle", "Contact Angles", "Water Contact Angle", "Wetting Angle"],
    "Reflectivity": ["Reflectivity", "Reflectance", "Reflection Loss"],
    "Pore Size": ["Pore Size", "Median Pore Size"],
    "Particle Size": ["Particle Size", "Average Particle Size", "Size Distribution"],
    "Density": ["Apparent Density"],
    "Solar Absorptance": ["Solar Absorptance", "Solar absorptance"],
    "Optical Properties": ["Infrared Emissivity", "Optical Transmittance", "Infrared Absorbance"],
    "Passive Film": ["Passive Film Thickness", "Passive Films", "Protective Oxide Layer"],
    "Oxidation Resistance": ["TGO Growth Rate"],
    "Oxygen Content": ["Oxygen Content"],
    "Surface Composition": ["Surface Composition"],
    "Surface Activity": ["Surface Activity"],
    "Surface Structure": ["Surface Structure"],
    "Interface Strength": ["Interface Strength"],
    "Surface Reaction Exchange Current": ["Surface Reaction Exchange Current"],
    "Normal Force": ["Normal Force"],
    "Volume Expansion Coefficient": ["Volume Expansion Coefficient"],
    "Indentation Fracture Toughness": ["Indentation Fracture Toughness"],
    "Permeability": ["Permeability"],
}

# %%
misc_properties_dict = {
    "Discharge Capacity": ["Discharge Capacity", "Capacity", "Specific Capacity", "Reversible Capacity", "Capacity Retention Rate"],
    "Hydrogen Storage Capacity": ["Hydrogen Storage Capacity", "Hydrogen Capacity", "Reversible Hydrogen Storage Capacity"],
    "Diffusion": ["Diffusion", "Diffusivity", "Diffusion Coefficients", "Diffusion Rate", "Diffusion Resistance", "Dislocation-core Diffusion"],
    "Radiation Resistance": ["Radiation Resistance", "Radiation Tolerance", "Irradiation Tolerance", "Radiation Damage", "Irradiation Hardening Resistance", "Irradiation Hardness"],
    "Composition": ["Composition", "Chemical Composition", "Elemental Distribution"],
    "Erosion Resistance": ["Erosion Resistance", "Erosion Wear Resistance", "Slurry Erosion Rate", "Erosion Rate"],
    "Wetting": ["Wetting"],
    "Bulk Modulus": ["Adiabatic Bulk Modulus", "Bulk Sound Speed"],
    "Temperature Metrics": ["Tm", "Ms", "Tl", "Tx", "TL", "MT Temperature", "N el Temperature"],
    "Valence Electron Concentration": ["Valence Electron Concentration", "VEC"],
    "Volume Fraction": ["Volume Fraction"],
    "Atomic Size": ["Atomic Size", "Atomic Size Difference", "Atomic Radii", "Mean Atomic Radius", "Wigner Seitz Radius"],
    "Mass Activity": ["Mass Activity"],
    "Zener Ratio": ["Zener Ratio", "Zener Anisotropy Ratio"],
    "Indentation Properties": ["Indentation-energy factor", "Micro Vickers Hardness"],
    "Dislocation Properties": ["Dislocation-core Diffusion", "Dislocation width", "Dislocation Velocity", "Dislocation Activities"],
    "Shear Resistance": ["Resistance to Shear Localization", "Interface Shear Resistance Force"],
    "Refrigerant Capacities": ["Effective Refrigerant Capacities", "Refrigerant Capacity", "Refrigeration Capacity", "Refrigerating Capacity"],
    "Free Energy": ["Gibbs Free Energy", "Helmholtz Free Energy"],
    "Spallation Resistance": ["Spallation Resistance", "Spalling Resistance"],
    "Wear Rate": ["Volume Wear Rate", "Specific Wear Rate", "Wear Mass Loss", "Wear Loss"],
    "Corrosion Resistance": ["Bio-corrosion Resistance", "Corrosion Resistances", "Corrosion potentials", "Corrosion current densities"],
    "Entropy": ["Entropy", "Entropy Change", "Configurational Entropy", "Configurational entropy", "Entropy Changes", "Change of Entropy"],
    "Electrochemical Properties": ["Half-wave Potential", "E1/2", "Surface Reaction Exchange Current", "Electrocatalytic Activities", "OER", "OER Performance", "HER Performance", "ORR Catalytic Activity"],
    "Hardness": ["Irradiation Hardness", "High-Temperature Strength"],
    "Energy Storage": ["Energy Density", "Volumetric Energy Storage Capacity"],
    "Glass-Forming Ability": ["Glass-Forming Ability"],
    "Thermal Expansion": ["Volume Expansion Coefficient", "Volumetric Expansion", "Linear Expansion Coefficient"],
    "Optical Properties": ["Optical Band Gap", "Absorption Bandwidth", "Extinction Coefficient", "Absorption energy", "Absorption Energy"],
    "Permeability": ["Effective Permeability"],
    "Elasticity": ["Elasticity", "Effective Elastic Modulus", "Elastic Storage Modulus", "Elastic Recovery Index"],
    "Tafel Slopes": ["Tafel Anode Slope", "Tafel Cathode Slope"],
    "Stress and Strain": ["Film Stress", "Strain Amplitude", "Stress Concentration", "Elastic Storage Modulus", "Back Stress", "Dilatational Strain"],
    "Density": ["Density", "Total Density", "Relative Density", "Apparent Density"],
    "Cohesive Energy": ["Cohesive Energy", "Lattice Elastic Strain Energy"],
    "Poisson's Ratio": ["Poisson's Ratio", "Poisson's Ratios", "Poisson's Coefficient"],
    "Weldability": ["Weldability"],
    "Swelling": ["Swelling", "Swelling Resistance", "Volumetric Swelling"],
    "Damping": ["Damping", "Damping Capability"],
    "Lifetime Properties": ["Lifetime", "Cycle Life", "Cycling Longevity", "Cycle Lives"],
    "Energy Absorption": ["Energy Absorption", "Impact Energy Absorption Density", "Energy Consumption"],
    "Cooling Efficiency": ["Cooling Efficiency", "Cooling Temperature Difference"],
    "Defects and Damage": ["Defect Size", "Defect Counts", "Defect Concentration", "Void Nucleation Rate", "Cavity Density", "Cavity Size"],
    "Thermal Properties": ["Thermodynamic Parameters", "Phase Transition Enthalpy"],
    "Electronegativity": ["Electro-negativity Difference", "Allen Electronegativity", "Allen's Electronegativity", "Pauling's Electronegativity"],
    "Energy Release Efficiency": ["Energy Release Efficiency"],
    "Power Density": ["Output Power Density", "Specific Power"],
    "Cycling Durability": ["Cycling Durability"],
    "Performance Metrics": ["Performance-Cost Ratio", "Conversion Efficiency", "Coulombic Efficiency", "Faradaic Efficiency"],
    "Absorption Properties": ["Light Absorbance", "Electromagnetic Wave Absorption"],
    "Saturation Rate": ["Saturation Rate"],
    "Peak Area": ["Peak Area"],
    "Detection Properties": ["Detection Range", "Detection Limit"],
    "Hall Measurement": ["Hall Measurement"],
    "Operating Temperature": ["Operating Temperature"],
    "Cooling Temperature Difference": ["Cooling Temperature Difference"],
    "Energy Barrier": ["Energy Barrier"],
    "Potential Energy": ["Potential Energy"],
    "EOS": ["EOS"],
    "Wave Speed": ["Wave Speed"],
    "Storage Capacity": ["Storage Capacity", "Reversible Storage Capacity"],
    "Solar Absorptivity": ["Solar Absorptivity"],
    "ZT Value": ["ZT Value"],
    "Mass Transport": ["Mass Transport", "Mass Transfer Paths"],
    "Recovery Strain": ["Recovery Strain"],
    "Sound Velocity": ["Sound Velocity"],
    "SRO": ["SRO"],
}

# %%
import csv

csv_filename="final_properties_list.csv"

with open(csv_filename,'w',newline="") as f:
    writer=csv.writer(f)

    writer.writerow(['Property','Type','Variations'])
    for k,v in mechanical_properties_dict.items():
        writer.writerow([k,'Mechanical',v])
    for k,v in thermal_properties_dict.items():
        writer.writerow([k,'Thermal',v])
    for k,v in electrical_properties_dict.items():
        writer.writerow([k,'Electrical',v])
    for k,v in chemical_properties_dict.items():
        writer.writerow([k,'Chemical',v])
    for k,v in magnetic_properties_dict.items():
        writer.writerow([k,'Magnetic',v])
    for k,v in structural_properties_dict.items():
        writer.writerow([k,'Structural',v])
    for k,v in surface_properties_dict.items():
        writer.writerow([k,'Surface',v])
    for k,v in misc_properties_dict.items():
        writer.writerow([k,'Miscellaneous',v])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
